# %%
import pandas as pd

# %%
raw = pd.read_csv("Pre-class Survey Survey Student Analysis Report.csv").dropna(how='all')
raw
# Out:
#                                             Unnamed: 0  \
# 10   it's a required course for ACCT ,self-declare ...
# 16                                                 NaN
# 20   major requirement,fulfill major requirement,ac...
# 21   this is my major,learn more about accounting,A...
# 22   it is required,graduate,Acct,OM,nope,I like Ac...
# ..                                                 ...
# 182  I need to obtain CPA ,get QP ,ACCT ,MGMT,N/A,A...
# 183  ,fulfill my major requirements,Accounting,Info...
# 184  I am an accounting student,advance my accounti...
# 185  1) it is required course of accounting major 2...
# 186  I would like to learn more about this subject,...
#
#                                             Unnamed: 1
# 10                                                 NaN
# 16                      2024,AGBA Focus,,Finance,,,,,,
# 20                end of this semester,big 4,,no,,,,,,
# 21   2025,Big 4,Big 4,Not sure,HK,Audit,HK,commerci...
# 22   2024,PWC and KPMG,/,/,BOC,Banking Intern,Big 4...
# ..                                                 ...
# 182  Spring 2022/23,PwC ,PwC ,N/A,Hk ,Audit ,No sur...
# 183  2024,CPA firm\, tax team,big4\, tax or consult...
# 184  2024,accounting firm,banks or accounting firms...
# 185  2024,Big 4; Western Securities,Finance (especi...
# 186  Fall 2023,Grant Thornton,Grant Thornton,Accoun...
#
# [169 rows x 2 columns]

# %%
set1 = raw['Unnamed: 0'].str.split(',', expand=True)
set2 = raw['Unnamed: 1'].str.split(',', expand=True)

# %%
set1[5].to_csv('whymajor.csv')

# %%
## questions
I am taking Advanced Managerial Accounting, because [one].
I am taking Advanced Managerial Accounting in order to [two].
What is your major? [three]
If you have a second major what is it? [four]
If you have a minor what is it? [five]
Why did you pick this major? [six]
What grade do you want? [seven]
What grade do you think you will get? [eight]
Do you plan to take the CPA exam? [nine]
Do you plan to take the CMA exam? [ten]
If so, where? (which country and system GAAP, IFRS, etc.) [eleven]"

# %%
# question 1: I am taking managerial accounting because:
q1=set1[0].dropna()
set1['q1required']=set1[0].str.contains('requi|need|major|acc|grad')
set1['q1learn']=set1[0].str.contains('learn')

# %%
set1[0].describe()
# Out:
# count                         168
# unique                        140
# top       it is a required course
# freq                           11
# Name: 0, dtype: object

# %%
set1['q1required'].value_counts(normalize=True) * 100
# Out:
# True     80.357143
# False    19.642857
# Name: q1required, dtype: float64

# %%
set1['q1learn'].value_counts(normalize=True) * 100
# Out:
# False    94.047619
# True      5.952381
# Name: q1learn, dtype: float64

# %% [markdown]
# # Pre-class Survey
#
# The following is analysis of last year's responses (since you still have time to fill our the survey).

# %% [markdown]
# # Question 1:
#
# ## _"I am taking Advanced Managerial Accounting, because"_
#
# - Most common answer: "It is a required course."
# - 80\%: 'required', 'need', 'major', etc...
# - 5\%: 'learn'

# %%
set1[1].describe()
# Out:
# count          168
# unique         134
# top       graduate
# freq            15
# Name: 1, dtype: object

# %%
set1['q2required']=set1[1].str.contains('requi|need|major|acc|grad')
set1['q2required'].value_counts(normalize=True) * 100
# Out:
# True     65.47619
# False    34.52381
# Name: q2required, dtype: float64

# %%
set1['q2learn']=set1[1].str.contains('learn')
set1['q1learn'].value_counts(normalize=True) * 100
# Out:
# False    94.047619
# True      5.952381
# Name: q1learn, dtype: float64

# %% [markdown]
# # Question 2:
#
# ## "I am taking Advanced Managerial Accounting in order to:"
# - Most common answer is: "graduate"
# - 65%: 'required', 'need', 'major', etc...
# - 94%: 'learn'

# %%
set1[5][131] #.dropna().value_counts().head(50)
# Out:
# 'I love accounting. When I solve some accounting problems\\'

# %%
set1[6][131] #.dropna().value_counts().head(50)
# Out:
# ' I feel great. '

# %%
set1['q2acct']=set1[2].str.contains('acc', case=False)
set1['q2acct'].value_counts(normalize=True)*100
# Out:
# True     80.952381
# False    19.047619
# Name: q2acct, dtype: float64

# %%
set1['q2fin']=set1[2].str.contains('fin', case=False)
set1['q2fin'].value_counts(normalize=True)*100
# Out:
# False    89.285714
# True     10.714286
# Name: q2fin, dtype: float64

# %% [markdown]
# ## Question 3: What is your major?
#
# - Accounting: 81\%
# - Finance: 10\%
# - The rest: Econ, Marketing, IS, Operations, GBUS

# %%
set1['q5interest']=set1[5].str.contains('inte|like|enjo|use|chal|want',case=False)
set1['q5interest'].value_counts(normalize=True)*100
# Out:
# False    50.0
# True     50.0
# Name: q5interest, dtype: float64

# %%
set1['q5stabjob']=set1[5].str.contains('stab|job|career|work|prosp',case=False)
set1['q5stabjob'].value_counts(normalize=True)*100
# Out:
# False    83.928571
# True     16.071429
# Name: q5stabjob, dtype: float64

# %%
set1['q5intro']=set1[5].str.contains('introvert',case=False)
set1['q5intro'].value_counts()
# Out:
# False    167
# True       1
# Name: q5intro, dtype: int64

# %%
set1['q5love']=set1[5].str.contains('love',case=False)
set1['q5love'].value_counts(normalize=True)
# Out:
# False    0.970238
# True     0.029762
# Name: q5love, dtype: float64

# %% [markdown]
# ## Why did you pick this major?
#
# - 50\% Interesting, enjoy, like, useful
# - 16\% Stability/get job
#
# - 2\% __LOVE__ accounting!
#
# - "Because I am an introvert.", "No idea.", "I like math and money.", "I made a mistake in life."
#
# - "I love accounting. When I solve some accounting problems I feel great."

# %%
set1[10].dropna().value_counts()
# Out:
#                                                                                        46
# Hong Kong                                                                              14
# HK                                                                                     11
# IFRS                                                                                   11
# HK\                                                                                     7
# NA                                                                                      6
# No                                                                                      6
# N/A                                                                                     5
# hk                                                                                      4
# HKICPA                                                                                  4
# /                                                                                       4
# GAAP                                                                                    2
# HKFRS                                                                                   2
# no                                                                                      2
# Hong Kong\                                                                              2
# Nil                                                                                     2
# Not yet sure                                                                            1
# Probably                                                                                1
# Australia IFRS                                                                          1
# Hong Kong IFRS                                                                          1
# maybe                                                                                   1
#  maybe                                                                                  1
# Yes                                                                                     1
# unknown now                                                                             1
# haven't think about yet                                                                 1
# Not decided yet                                                                         1
# not yet                                                                                 1
# Yes.                                                                                    1
# No.                                                                                     1
# May                                                                                     1
# HKICPA\                                                                                 1
# HKICPA QP                                                                               1
# not applicable                                                                          1
# Definitely yes                                                                          1
# not yet decided                                                                         1
# i have no idea                                                                          1
# Not sure                                                                                1
# HK IFRS                                                                                 1
# No\                                                                                     1
# //                                                                                      1
# hong kong                                                                               1
# none                                                                                    1
# Hk GAAP                                                                                 1
# Not Sure                                                                                1
# Not yet decided                                                                         1
# iFRS                                                                                    1
# Hk                                                                                      1
# yes                                                                                     1
# Maybe                                                                                   1
# Maybe not                                                                               1
#  I would like to equip myself with such impactful and meaningful knowledge. Lastly\     1
# Hong Kong (IFRS)                                                                        1
# None                                                                                    1
# Hk Ifrs                                                                                 1
# HK?                                                                                     1
# United Kingdom                                                                          1
# Name: 10, dtype: int64

# %%
set1['q10hk']=set1[10].str.contains('hk|hong',case=False)
set1['q10hk'].value_counts()
# Out:
# False    114
# True      54
# Name: q5hk, dtype: int64

# %%
set1['q10ifrs']=set1[10].str.contains('ifrs',case=False)
set1['q10ifrs'].value_counts()
# Out:
# False    151
# True      17
# Name: q5ifrs, dtype: int64

# %%
set1['q10gaap']=set1[10].str.contains('gaap',case=False)
set1['q10gaap'].value_counts()
# Out:
# False    165
# True       3
# Name: q10gaap, dtype: int64

# %% [markdown]
# # Where/What system:
# - 54 Hong Kong
# - 17 IFRS
# - 3 GAAP
# - 1 UK
# - 1 Australia

# %%
# set2['q4grad']=set1[3].str.contains('gaap',case=False)
# set1['q4grad'].value_counts()

# %%
# set2[3].value_counts().head(50) # grad school

# %%
# set2[7].value_counts().head(50) # where next j

# %%
# set2[5].value_counts().head(50) # what do next year
set2['nextAudacc']=set2[7].str.contains('aud|acc|big|pwc|ass',case=False)
set2['nextAudacc'].value_counts()
# Out:
# False    111
# True      55
# Name: nextAudacc, dtype: int64

# %%
set2['nextbank']=set2[7].str.contains('bank',case=False)
set2['nextbank'].value_counts()
# Out:
# False    142
# True      24
# Name: nextbank, dtype: int64

# %%
set2['nextfinan']=set2[7].str.contains('finan|fund',case=False)
set2['nextfinan'].value_counts()
# Out:
# False    156
# True      10
# Name: nextfinan, dtype: int64

# %% [markdown]
# ## What do you want to do next year?
#
# - 55 Accounting/Auditing/Big 4
# - 24 Banking
# - 10 Consulting

# %%
set2[14].value_counts().head(50) # where next j
# Out:
#  but one certain thing is that I will stay in the financial services industry.     1
# Large financial institution\                                                       1
#  but I want to work in US to feel the atmosphere.                                  1
# Name: 14, dtype: int64

# %%
# set2[5].value_counts().head(50) # what do next year
set2['nextAudacc']=set2[7].str.contains('aud|acc|big|pwc|ass',case=False)
set2['nextAudacc'].value_counts()
# Out:
# False    111
# True      55
# Name: nextAudacc, dtype: int64

# %%
set2[7].value_counts().head(50) # what do next year
set2['nextbank']=set2[7].str.contains('bank',case=False)
set2['nextbank'].value_counts()
# Out:
# False    142
# True      24
# Name: nextbank, dtype: int64

# %%
set2['nextfinan']=set2[7].str.contains('finan|fund',case=False)
set2['nextfinan'].value_counts()
# Out:
# False    156
# True      10
# Name: nextfinan, dtype: int64

# %% [markdown]
# ## What do you want to do next year?
#
# - 55 Accounting/Auditing/Big 4
# - 24 Banking
# - 10 Consulting

# %% [markdown]
# ## What about 10 years?
#
# - Accounting, Banking, Consulting, Data Science.
# - CEO, Venture Capital, Top luxury group, Founder.
# - Inland Revenue Department, Hong Kong Government.
# - Retired, working abroad (US, Singapore, UK, Indo., CA, UK).
# - Traveling, farming, actor, singer/artist (viu.tv), Fire Department.
# - __MYSTERY SHOPPER__

# %%
set2[9].value_counts()
# Out:
# Hong Kong                    20
#                              15
# HK                           15
# Not sure                      4
# hk                            3
#                              ..
# In my home country\           1
# HK/Mainland China             1
# Non-front office jobs\        1
# Accounting industry           1
# banks or accounting firms     1
# Name: 9, Length: 106, dtype: int64

# %%
set2[8].value_counts()
# Out:
#                         13
# Accountant               5
# Accounting               3
# not sure                 3
# Hong Kong                3
#                         ..
# Consulting               1
# Accounting industry      1
# Product Management       1
#  probably Accounting     1
# Auditing                 1
# Name: 8, Length: 135, dtype: int64

# %%
set2[7].value_counts()
# Out:
#                                    11
# Auditor                             5
# HK                                  5
# Hong Kong                           4
# Accountant                          4
#                                    ..
# Financial relatives                 1
# Marketing or accounting related     1
#  in the middle or back office       1
# Accounting industry                 1
# Auditing                            1
# Name: 7, Length: 126, dtype: int64

# %%
set2[6].value_counts()
# Out:
# HK                                       22
# Hong Kong                                18
#                                          11
# Hong Kong                                 5
# hk                                        5
#                                          ..
# Singapore or Hong Kong                    1
# UK/US                                     1
# Investment Banking-related positions\     1
# Accounting industry                       1
# Singapore                                 1
# Name: 6, Length: 98, dtype: int64

# %%
set2[14].value_counts()
# Out:
#  but one certain thing is that I will stay in the financial services industry.     1
# Large financial institution\                                                       1
#  but I want to work in US to feel the atmosphere.                                  1
# Name: 14, dtype: int64

# %%
set2.tail(60)
# Out:
#                                   0  \
# 127                       next year
# 128                    By June 2023
# 129                            2024
# 130                        Jun 2024
# 131                            2024
# 132                            2024
# 133                            2024
# 134                        May 2024
# 135                       June 2024
# 136                            2023
# 137                       Next Year
# 138                     2024 Spring
# 139                        2024 Jun
# 140                        Dec 2023
# 141                           2024
# 142                            2024
# 143                     2023 Winter
# 144                            2024
# 145                            2024
# 146                     2023 Spring
# 147                            2024
# 148                            2024
# 149                        Jun 2023
# 150                         Jun2024
# 151                      Year 2024
# 152                            2024
# 153                     2024 Spring
# 154                            2024
# 155                            2024
# 156                        Dec 2023
# 157                     2024 spring
# 158                        2025 Jan
# 159                    2024 summer
# 160                            2024
# 161  Finish taking courses required
# 162                          Year 4
# 163                            2024
# 164                       July 2024
# 165                            2024
# 166                             204
# 167                            2023
# 168                            2024
# 169                            2024
# 170                            2024
# 171                2024 Spring sem
# 172                   this semester
# 173                            2024
# 174                            2024
# 175                            2024
# 176                       2024 fall
# 177                        May 2023
# 178                       June 2024
# 179                            2024
# 180                       June 2024
# 181                        May 2024
# 182                  Spring 2022/23
# 183                            2024
# 184                            2024
# 185                            2024
# 186                       Fall 2023
#
#                                                      1  \
# 127                             a small auditing firm
# 128                                             Banks\
# 129                                               Big4
# 130                                     Retail company
# 131                         a online accessories shop\
# 132                                           Banking
# 133                                 A local audit firm
# 134                                 Telecommunication\
# 135                                              HSBC\
# 136                                 accounting related
# 137                                Hospital Authority
# 138                                           Deloitte
# 139                          Intern in commerical bank
# 140                                          Deloitte
# 141                                          Ares SSG\
# 142                                           CPA firm
# 143                    audit/marketing/tutorial center
# 144                                        audit firm\
# 145  NGO and limited company in Property developmen...
# 146                                                PwC
# 147                                                PwC
# 148                                          Marketing
# 149                                              Big 4
# 150                                           Deloitte
# 151                                                N/A
# 152               Deloitte (Tax and business advisory)
# 153                                          Not many\
# 154                                    accounting firm
# 155                                              HKSAR
# 156                           HKSAR Efficiency Office\
# 157                                Accounting company.
# 158                     Local CPA Firm / Tech start up
# 159                                           Big Four
# 160                                   Auditing company
# 161                               Crowe HK CPA Limited
# 162                                         Marketing
# 163                                               PwC\
# 164                                        Autobahn88\
# 165                                  Local audit firm\
# 166                                              Audit
# 167                                                PwC
# 168                                         government
# 169                                               None
# 170                                     Hang Seng Bank
# 171                                               Pwc
# 172                                                PwC
# 173                           PwC and local audit firm
# 174                                         Audit firm
# 175                                               PwC\
# 176                              A Technology company
# 177                                         UNICEF HK\
# 178                             Local consulting firm\
# 179                                               Big4
# 180                                          DBS Bank\
# 181                                             PwC HK
# 182                                               PwC
# 183                                          CPA firm\
# 184                                    accounting firm
# 185                          Big 4; Western Securities
# 186                                     Grant Thornton
#
#                                                      2  \
# 127        i want to work as an IT auditor or analysis
# 128                    tech firms and accounting firms
# 129                                               bank
# 130
# 131                                             tutor\
# 132                                           Banking
# 133                                      Probably big4
# 134                          IT and start up companies
# 135                                    Hang Seng Bank\
# 136                                 accounting related
# 137                                             Banks
# 138                                         Accounting
# 139                                Intern in assurance
# 140
# 141                                                PwC
# 142
# 143
# 144                              governemnt department
# 145                                           CPA firm
# 146                                                 No
# 147
# 148                             Maybe one of the Big 4
# 149                                                Tax
# 150                                      KPMG/Deloitte
# 151                                              Big 4
# 152        Morgan Stanley in this summer (2023 summer)
# 153   most are small companies as I was focused on ...
# 154                              accounting or IT firm
# 155                                              HKSAR
# 156                                         HKSAR IRD\
# 157                                          Banking.
# 158                                              Big 4
# 159                                           Big Four
# 160                                              Big 4
# 161                                   Accounting field
# 162                                Telecommunications
# 163                                          CPA firm\
# 164   a company that sells race car components. Amp...
# 165                                        IRD and PWC
# 166                                           Banking
# 167                                                PwC
# 168                                               bank
# 169                                   Accounting firms
# 170                                 Banking/consulting
# 171                                             Audit
# 172                                                PwC
# 173                tax or other accounting related job
# 174                                                idk
# 175   Education for Good and the Hong Kong Government
# 176        Consulting positions in big name companies
# 177                                                EY\
# 178                          PwC and HSBC in Hong Kong
# 179                                               Big4
# 180                                                PwC
# 181                                          Auditing.
# 182                                               PwC
# 183                                           tax team
# 184                          banks or accounting firms
# 185               Finance (especially equity tesearch)
# 186                                     Grant Thornton
#
#                                                      3  \
# 127                             maybe IT related stuff
# 128                                            Banking
# 129                                         Accounting
# 130                                           Not sure
# 131                                          officers\
# 132                     Finance or information system
# 133                                               ACCT
# 134                                Big 4 in Hong Kong\
# 135                                               HKMA
# 136                                         Accounting
# 137                                           Finance
# 138                                   Hotel Management
# 139                                      maybe Finance
# 140                                            Finance
# 141                                           banking
# 142
# 143
# 144                                      big 4 or bank
# 145                                    Accounting & IT
# 146                                          Economics
# 147
# 148                                      Maybe finance
# 149                                                MBA
# 150
# 151                               Non-business related
# 152                                           business
# 153                                   Preferably Big 4
# 154                                                 no
# 155    Skills for investment or starting up a business
# 156                                              HSBC\
# 157                                        Accounting.
# 158
# 159                           Accounting and economics
# 160                                                MBA
# 161                                         Accounting
# 162
# 163                                   Fintech startup
# 164                               a watch manufacturer
# 165                                        Audit firm
# 166                                      Non business
# 167                                                 HK
# 168                                            finance
# 169                             I don’t have such plan
# 170                                    Econ/IS-related
# 171                                                No
# 172                                                MBA
# 173                                                N/A
# 174                                                idk
# 175                                  Citi bank or MUFG
# 176                                 Business analysis
# 177                                               etc.
# 178
# 179                                               ACCT
# 180                                      Goldman Sachs
# 181                               All required course.
# 182                                                N/A
# 183                                              big4\
# 184                                         accounting
# 185  Accounting (for information) or Development ec...
# 186                                         Accounting
#
#                                  4  \
# 127                      Hong Kong
# 128                             NA
# 129                          Banks
# 130                      Hong Kong
# 131                mystery shopper
# 132                            HK
# 133                      Hong Kong
# 134         first choice maybe Pwc
# 135                        Banking
# 136                     Hong Kong
# 137                          Banks
# 138                             HK
# 139                             HK
# 140                             HK
# 141  banking or investment related
# 142                      Hong Kong
# 143                             HK
# 144                             NA
# 145                      Hong Kong
# 146                      Hong Kong
# 147                            N/A
# 148                             HK
# 149                          Big 4
# 150                             HK
# 151                          Big 4
# 152                             HK
# 153              Accounting or Law
# 154                      Hong Kong
# 155                             HK
# 156      Storius Limited (startup)
# 157                 Small company.
# 158                          Audit
# 159                       Big Four
# 160                             HK
# 161                             HK
# 162                      Hong Kong
# 163                           HSBC
# 164      Data science related role
# 165                            N/A
# 166                             HK
# 167                            PwC
# 168                             hk
# 169               Accounting firms
# 170                      Hong Kong
# 171                           Pwc
# 172                            PwC
# 173                  Business firm
# 174                 maybe Big Four
# 175                            LSE
# 176                 HK or Shenzhen
# 177                              /
# 178                   Data Science
# 179                           Big4
# 180                 Finance Master
# 181                            HK\
# 182                            Hk
# 183              tax or consulting
# 184      banks or accounting firms
# 185                      Hong Kong
# 186                             HK
#
#                                                      5  \
# 127                  not external auditing related job
# 128                                        In banking\
# 129                                            Finance
# 130                           Job related to business\
# 131                             Not yet received offer
# 132  Finance like product control or big 4 transact...
# 133                                              Audit
# 134                                                MBA
# 135                                                N/A
# 136                                 accounting related
# 137                                             Banker
# 138                                   Big 4 associate
# 139                                          assurance
# 140                                            Banking
# 141                                          Hong Kong
# 142                                            Auditor
# 143                             create my own business
# 144                                                 HK
# 145                                      Big 4 auditor
# 146                                  Corporate Finance
# 147                                 Maybe IRD or Big4?
# 148                                 Accounting related
# 149                                                Tax
# 150                                              Audit
# 151                             Accounting related job
# 152                                  investment banks
# 153                                          Hong Kong
# 154                                         accountant
# 155                           Government work (intern)
# 156                                             A bank
# 157                                        Accounting.
# 158                                              Big 4
# 159                           Accountant or consultant
# 160                                         Accounting
# 161                                 Tax/Advisory/Audit
# 162                        Assistant Network engineer
# 163                                                N/A
# 164                             Master in Data Science
# 165                                                HK
# 166                                  Business related
# 167                                            Auditor
# 168                           maybe bank or government
# 169                                         Accountant
# 170                                 Banking/consulting
# 171                                             Audit
# 172                                                PwC
# 173                             Accounting related job
# 174                             maybe being an auditor
# 175                                               HSBC
# 176                                        Consulting
# 177                                                  /
# 178                                          Hong Kong
# 179                                               Big4
# 180                                    Investment Bank
# 181                                         audit firm
# 182                                             Audit
# 183                                            finance
# 184                   financial analyst or consultant
# 185                                      Finance - IBD
# 186                                           Auditing
#
#                                                      6  \
# 127                                          Hong Kong
# 128                                             in hk.
# 129                                               Bank
# 130                                            finance
# 131
# 132              Mainland China (Shanghai or Shenzhen)
# 133                                          Hong Kong
# 134                                          Hong Kong
# 135                                          Hong Kong
# 136                                         Hong Kong
# 137                                   Investment Banks
# 138                                         Outside HK
# 139                                                 HK
# 140                                           not sure
# 141                                           banking
# 142                                          Hong Kong
# 143                                                 HK
# 144                             accountant or advisory
# 145                                          Hong Kong
# 146                                          Hong Kong
# 147                                                IRD
# 148                                                 HK
# 149                             Consulting company/cpa
# 150                                                 HK
# 151                                              Big 4
# 152                                                 HK
# 153                                      Tax Associate
# 154                                          Hong Kong
# 155                                                 HK
# 156  No plans (even if I did I have to work for a f...
# 157                                              Bank.
# 158                                         consultant
# 159                      Big Four or consulting firms
# 160                                                 HK
# 161                                                 HK
# 162                                                USA
# 163                                               HSBC
# 164                                               Nil\
# 165                                           auditor
# 166                                                 HK
# 167                                                PwC
# 168                                                 hk
# 169                                         Government
# 170                                          Hong Kong
# 171                                     Probably bank
# 172                                                PwC
# 173                       Business firm or government
# 174                                                idk
# 175                        Commercial banking analyst
# 176                                                 HK
# 177                                           Big Four
# 178           Consultant specialises in the tech field
# 179                                               Big4
# 180                 Accounting / Financial Controllers
# 181                                           Auditor\
# 182                                           No sure
# 183                                                 hk
# 184                          banks or accounting firms
# 185                                          Singapore
# 186                                                 HK
#
#                                     7  \
# 127                        IT auditor
# 128                 In banking in hk.
# 129                        Accounting
# 130         Hong Kong/other countries
# 131                             Big 4
# 132  More finance or consulting work
# 133                        Consultant
# 134            Accountant (Audit/Tax)
# 135                Commercial Banking
# 136                accounting related
# 137                            Banker
# 138                           Manager
# 139                   maybe assurance
# 140                           Banking
# 141                         Hong Kong
# 142                           Auditor
# 143
# 144                                HK
# 145                     Big 4 auditor
# 146                 Corporate Finance
# 147            Accounting related job
# 148                Accounting related
# 149              Advisory/Consultancy
# 150                Financial advisory
# 151            Accounting related job
# 152                 investment banks
# 153                  Canada/Hong Kong
# 154                           manager
# 155                   Government work
# 156        Bank as management trainee
# 157                           Banker.
# 158                        consultant
# 159          Accountant or consultant
# 160                        Accounting
# 161                    Commercial/Tax
# 162                 Network engineer
# 163                Commercial Banking
# 164             pursuing master study
# 165                                HK
# 166                 Business related
# 167                           Auditor
# 168          maybe bank or government
# 169                        Accountant
# 170                Banking/consulting
# 171                        Operation
# 172                               PwC
# 173                Accounting related
# 174   maybe something more challenged
# 175                         In the UK
# 176                           No idea
# 177             management consultant
# 178                         Hong Kong
# 179                              Big4
# 180                   Investment Bank
# 181               finance researcher.
# 182                            Audit
# 183                 tax or consulting
# 184   financial analyst or consultant
# 185                      Fund manager
# 186                          Auditing
#
#                                                      8  \
# 127                                  ibank related job
# 128                                             In HK\
# 129                                         Accounting
# 130  In the same industry but maybe different position
# 131                                         Accountant
# 132      Either finance related or consulting related
# 133                      Corporate development manager
# 134                                          Hong Kong
# 135                                          Hong Kong
# 136                                 accounting related
# 137                                          Partners
# 138                                  Senior Management
# 139                                    maybe assurance
# 140                                   Start a business
# 141                                           banking
# 142
# 143
# 144                             accountant or advisory
# 145                 Commercial Company Finance Manager
# 146                                    Commercial Firm
# 147                             Accounting related job
# 148                                 Accounting related
# 149                                            Partner
# 150                                 Financial advisory
# 151                               Taxation related job
# 152                                   investment banks
# 153                             Manager grade in Big 4
# 154                                            manager
# 155       May want to try something new like start up?
# 156                  management trainee (any position\
# 157                                            Banker.
# 158                                         consultant
# 159               Accountant or consultant or analyst
# 160                                         Accounting
# 161                               Civil servants (IRD)
# 162
# 163                                               HSBC
# 164                                               Nil\
# 165                                           Auditor
# 166                                           Unknown
# 167                                     Risk assurance
# 168                           maybe bank or government
# 169                                         Accountant
# 170                                 Banking/consulting
# 171                                         Operation
# 172                                         It depends
# 173                                 Accounting related
# 174                                                idk
# 175         Commercial banking analyst or esg analyst
# 176                                            No idea
# 177                                  Probably the same
# 178                            Senior consultant? Haha
# 179                                                  /
# 180                 Accounting / Financial Controllers
# 181                                 Probably still HK\
# 182                                        Retirement
# 183                                           not sure
# 184                    financial analyst or consultant
# 185                                       Fund manager
# 186                                           Auditing
#
#                                                 9  \
# 127                                     Hong Kong
# 128   but hoping to have flexibility in mobility.
# 129                                          Bank
# 130                               Same as 5 years
# 131                                         Big 4
# 132                                            HK
# 133                                     Hong Kong
# 134                        Accountant (Audit/Tax)
# 135                            Commercial Banking
# 136                                     Hong Kong
# 137                              Consulting Firms
# 138                                    Outside HK
# 139                                            HK
# 140                                      Not sure
# 141                                      banking
# 142
# 143
# 144                        accountant or advisory
# 145                                     Hong Kong
# 146                                     Hong Kong
# 147                                           IRD
# 148                     Maybe somewhere in Europe
# 149                        Consulting company/CPA
# 150                                        London
# 151                     Inland Revenue Department
# 152                                            HK
# 153                  Hopefully Partner? Not sure\
# 154                                     Hong Kong
# 155                                           HK?
# 156                       preferiably IS related)
# 157                                         Bank.
# 158                                Bain & Company
# 159       Accounting or consulting firms or banks
# 160                                            HK
# 161                                            HK
# 162
# 163                            Commercial Banking
# 164                         pursuing master study
# 165                                       Banker
# 166                                       Unknown
# 167                                           PwC
# 168                                            hk
# 169                                    Government
# 170                                     Hong Kong
# 171                                          Bank
# 172                                    It depends
# 173                   Business firm or government
# 174                                           idk
# 175                          Have not thought of
# 176                                            HK
# 177                         management consultant
# 178                           In-house consultant
# 179                                             /
# 180            Accounting / Financial Controllers
# 181                                  same company
# 182                                   No specific
# 183                                      not sure
# 184                     banks or accounting firms
# 185                                            US
# 186                                            HK
#
#                                                     10  \
# 127                                               None
# 128  Still in banking but hopefully I’ve risen thro...
# 129                                               None
# 130                                    Other countries
# 131                                        Accountant
# 132                                               None
# 133                                               None
# 134                                      Businesswoman
# 135                                 Commercial Banking
# 136                                               None
# 137                                               None
# 138                                               None
# 139                                               None
# 140                                               None
# 141                                          Hong Kong
# 142                                               None
# 143                                               None
# 144                                                 HK
# 145                                               None
# 146                                               None
# 147                                               None
# 148                                               None
# 149                                               None
# 150                                               None
# 151                                               None
# 152                                               None
# 153                      a lot can change in 10 years.
# 154                                               None
# 155                                               None
# 156                       Large financial institution\
# 157                                               None
# 158                                               None
# 159                                               None
# 160                                               None
# 161                                               None
# 162                                               None
# 163                             Maybe start a business
# 164                                                USA
# 165                                                 HK
# 166                                               None
# 167                                               None
# 168                                               None
# 169                                               None
# 170                                               None
# 171                                               None
# 172                                               None
# 173                                               None
# 174                                               None
# 175                                Any first tier bank
# 176                                               None
# 177  probably the same but do not know whether I wi...
# 178                                          Hong Kong
# 179                                               None
# 180                                    Investment Bank
# 181                                      The same job!
# 182                                               None
# 183                                           not sure
# 184                                               None
# 185                                               None
# 186                                               None
#
#                                                 11  \
# 127                                           None
# 128  In banking and with a more specialised field
# 129                                           None
# 130                                           None
# 131                                       Traveler
# 132                                           None
# 133                                           None
# 134                                      Hong Kong
# 135                                      Hong Kong
# 136                                           None
# 137                                           None
# 138                                           None
# 139                                           None
# 140                                           None
# 141                                           None
# 142                                           None
# 143                                           None
# 144                                           None
# 145                                           None
# 146                                           None
# 147                                           None
# 148                                           None
# 149                                           None
# 150                                           None
# 151                                           None
# 152                                           None
# 153                               Canada/Hong Kong
# 154                                           None
# 155                                           None
# 156                            preferiably a bank.
# 157                                           None
# 158                                           None
# 159                                           None
# 160                                           None
# 161                                           None
# 162                                           None
# 163                                        At home
# 164                                 Data scientist
# 165                                           None
# 166                                           None
# 167                                           None
# 168                                           None
# 169                                           None
# 170                                           None
# 171                                           None
# 172                                           None
# 173                                           None
# 174                                           None
# 175                                           None
# 176                                           None
# 177                                      Uncertain
# 178                                           None
# 179                                           None
# 180                                           None
# 181                                  To be honest\
# 182                                           None
# 183                                       not sure
# 184                                           None
# 185                                           None
# 186                                           None
#
#                                                     12  \
# 127                                               None
# 128                                       In HK or US.
# 129                                               None
# 130                                               None
# 131                            Travel around the world
# 132                                               None
# 133                                               None
# 134                                               None
# 135                                               None
# 136                                               None
# 137                                               None
# 138                                               None
# 139                                               None
# 140                                               None
# 141                                               None
# 142                                               None
# 143                                               None
# 144                                               None
# 145                                               None
# 146                                               None
# 147                                               None
# 148                                               None
# 149                                               None
# 150                                               None
# 151                                               None
# 152                                               None
# 153                                               None
# 154                                               None
# 155                                               None
# 156  Not sure. I'll see where the job market carrie...
# 157                                               None
# 158                                               None
# 159                                               None
# 160                                               None
# 161                                               None
# 162                                               None
# 163                                               None
# 164                                     Data scientist
# 165                                               None
# 166                                               None
# 167                                               None
# 168                                               None
# 169                                               None
# 170                                               None
# 171                                               None
# 172                                               None
# 173                                               None
# 174                                               None
# 175                                               None
# 176                                               None
# 177                                               None
# 178                                               None
# 179                                               None
# 180                                               None
# 181   I want to be a farmer if possible (which mean...
# 182                                               None
# 183                                               None
# 184                                               None
# 185                                               None
# 186                                               None
#
#                                                     13  \
# 127                                               None
# 128                                               None
# 129                                               None
# 130                                               None
# 131                                               None
# 132                                               None
# 133                                               None
# 134                                               None
# 135                                               None
# 136                                               None
# 137                                               None
# 138                                               None
# 139                                               None
# 140                                               None
# 141                                               None
# 142                                               None
# 143                                               None
# 144                                               None
# 145                                               None
# 146                                               None
# 147                                               None
# 148                                               None
# 149                                               None
# 150                                               None
# 151                                               None
# 152                                               None
# 153                                               None
# 154                                               None
# 155                                               None
# 156  Not sure. I'll see where the job market carrie...
# 157                                               None
# 158                                               None
# 159                                               None
# 160                                               None
# 161                                               None
# 162                                               None
# 163                                               None
# 164                                          Hong Kong
# 165                                               None
# 166                                               None
# 167                                               None
# 168                                               None
# 169                                               None
# 170                                               None
# 171                                               None
# 172                                               None
# 173                                               None
# 174                                               None
# 175                                               None
# 176                                               None
# 177                                               None
# 178                                               None
# 179                                               None
# 180                                               None
# 181                                           No sure\
# 182                                               None
# 183                                               None
# 184                                               None
# 185                                               None
# 186                                               None
#
#                                                     14                    15  \
# 127                                               None                  None
# 128                                               None                  None
# 129                                               None                  None
# 130                                               None                  None
# 131                                               None                  None
# 132                                               None                  None
# 133                                               None                  None
# 134                                               None                  None
# 135                                               None                  None
# 136                                               None                  None
# 137                                               None                  None
# 138                                               None                  None
# 139                                               None                  None
# 140                                               None                  None
# 141                                               None                  None
# 142                                               None                  None
# 143                                               None                  None
# 144                                               None                  None
# 145                                               None                  None
# 146                                               None                  None
# 147                                               None                  None
# 148                                               None                  None
# 149                                               None                  None
# 150                                               None                  None
# 151                                               None                  None
# 152                                               None                  None
# 153                                               None                  None
# 154                                               None                  None
# 155                                               None                  None
# 156                       Large financial institution\   preferiably a bank.
# 157                                               None                  None
# 158                                               None                  None
# 159                                               None                  None
# 160                                               None                  None
# 161                                               None                  None
# 162                                               None                  None
# 163                                               None                  None
# 164                                               None                  None
# 165                                               None                  None
# 166                                               None                  None
# 167                                               None                  None
# 168                                               None                  None
# 169                                               None                  None
# 170                                               None                  None
# 171                                               None                  None
# 172                                               None                  None
# 173                                               None                  None
# 174                                               None                  None
# 175                                               None                  None
# 176                                               None                  None
# 177                                               None                  None
# 178                                               None                  None
# 179                                               None                  None
# 180                                               None                  None
# 181   but I want to work in US to feel the atmosphere.                  None
# 182                                               None                  None
# 183                                               None                  None
# 184                                               None                  None
# 185                                               None                  None
# 186                                               None                  None
#
#        16 nextAudacc nextbank nextfinan
# 127  None       True    False     False
# 128  None      False     True     False
# 129  None       True    False     False
# 130  None      False    False     False
# 131  None       True    False     False
# 132  None      False    False      True
# 133  None      False    False     False
# 134  None       True    False     False
# 135  None      False     True     False
# 136  None       True    False     False
# 137  None      False     True     False
# 138  None      False    False     False
# 139  None       True    False     False
# 140  None      False     True     False
# 141  None      False    False     False
# 142  None       True    False     False
# 143  None      False    False     False
# 144  None      False    False     False
# 145  None       True    False     False
# 146  None      False    False      True
# 147  None       True    False     False
# 148  None       True    False     False
# 149  None      False    False     False
# 150  None      False    False      True
# 151  None       True    False     False
# 152  None      False     True     False
# 153  None      False    False     False
# 154  None      False    False     False
# 155  None      False    False     False
# 156  None      False     True     False
# 157  None      False     True     False
# 158  None      False    False     False
# 159  None       True    False     False
# 160  None       True    False     False
# 161  None      False    False     False
# 162  None      False    False     False
# 163  None      False     True     False
# 164  None      False    False     False
# 165  None      False    False     False
# 166  None      False    False     False
# 167  None       True    False     False
# 168  None      False     True     False
# 169  None       True    False     False
# 170  None      False     True     False
# 171  None      False    False     False
# 172  None       True    False     False
# 173  None       True    False     False
# 174  None      False    False     False
# 175  None      False    False     False
# 176  None      False    False     False
# 177  None      False    False     False
# 178  None      False    False     False
# 179  None       True    False     False
# 180  None      False     True     False
# 181  None      False    False      True
# 182  None       True    False     False
# 183  None      False    False     False
# 184  None      False    False      True
# 185  None      False    False      True
# 186  None       True    False     False

# %%
set2.to_csv('hopesanddreams.csv')
